# %%
# plot c-index and confidence interval for each transformation + region for each dataset and then univariate volume

import pandas as pd
import matplotlib.pyplot as plt

# %%
survival_results_df = pd.read_excel("/home/bhkuser1/bhklab/radiomics/PublicDatasets/procdata/HeadNeck/TCIA_RADCURE/readii-fmcib/readii-fmcib_analysis/ESTRO2025_fmcib_survival_results.xlsx", header=0)

# %%
survival_results_df
# Out:
#                     dataset features transform   region  c_index  low_ci  \
# 0                   RADCURE    fmcib  original     none    0.671   0.627
# 1                   RADCURE    fmcib  shuffled     full    0.540   0.494
# 2                   RADCURE    fmcib  shuffled      gtv    0.653   0.608
# 3                   RADCURE    fmcib  shuffled  non-gtv    0.574   0.526
# 4                   RADCURE    fmcib   sampled     full    0.546   0.501
# 5                   RADCURE    fmcib   sampled      gtv    0.654   0.608
# 6                   RADCURE    fmcib   sampled  non-gtv    0.552   0.506
# 7                   RADCURE   volume  original     none    0.705   0.688
# 8   HEAD-NECK-RADIOMICS-HN1    fmcib  original     none    0.668   0.610
# 9   HEAD-NECK-RADIOMICS-HN2    fmcib  shuffled     full    0.554   0.486
# 10  HEAD-NECK-RADIOMICS-HN3    fmcib  shuffled      gtv    0.661   0.600
# 11  HEAD-NECK-RADIOMICS-HN4    fmcib  shuffled  non-gtv    0.627   0.564
# ...

# %%
survival_results_df.to_dict(orient='records')
# Out:
# [{'dataset': 'RADCURE',
#   'features': 'fmcib',
#   'transform': 'original',
#   'region': 'none',
#   'c_index': 0.671,
#   'low_ci': 0.627,
#   'high_ci': 0.715,
#   'p_value': 0.0001},
#  {'dataset': 'RADCURE',
#   'features': 'fmcib',
#   'transform': 'shuffled',
#   'region': 'full',
#   'c_index': 0.54,
#   'low_ci': 0.494,
#   'high_ci': 0.585,
#   'p_value': 0.088},
#  {'dataset': 'RADCURE',
#   'features': 'fmcib',
#   'transform': 'shuffled',
#   'region': 'gtv',
#   'c_index': 0.653,
#   'low_ci': 0.608,
#   'high_ci': 0.698,
#   'p_value': 0.0001},
#  {'dataset': 'RADCURE',
#   'features': 'fmcib',
#   'transform': 'shuffled',
#   'region': 'non-gtv',
#   'c_index': 0.574,
#   'low_ci': 0.526,
#   'high_ci': 0.623,
#   'p_value': 0.003},
#  {'dataset': 'RADCURE',
#   'features': 'fmcib',
#   'transform': 'sampled',
#   'region': 'full',
#   'c_index': 0.546,
#   'low_ci': 0.501,
#   'high_ci': 0.591,
#   'p_value': 0.045},
#  {'dataset': 'RADCURE',
# ...
